# %% [markdown]
# interpolation, use scipy
#
# FORTRAN old language
#
# numpy for creating data with random package, to frame data in suitable structures

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
#plt.style.use('ggplot')
# %precision 4
#np.set_printoptions(suppress=True)
# Out:
# '%.4f'

# %% [markdown]
# ## Interpolation:
#
# `scipy.interpolate` is useful for fitting a function from experimental data and thus evaluating points where no measure exists. The module is based on the FITPACK Fortran subroutines.

# %% [markdown]
# conveniente to use in some cases, but not always, in most of the cases is just a shortcut to deal with intermediate problems
#
# use **interpolate** scipy package, based on FORTRAN

# %%
# the actual measurements
measured_time = np.linspace(0, 1, 10)  #time valuels
noise = (np.random.random(10)*2 - 1) * 1e-1  #adding some noise
measures = np.sin(2 * np.pi * measured_time) + noise #evaluate a sinusoid function of time, adding the noise

# %%
from scipy.interpolate import interp1d
# linear interpolation
linear_interp = interp1d(measured_time, measures)

#interp1D->  1D function  (x_values,y_values)

# %% [markdown]
# The kind of interpolation can be specified: linear is the default;  *zero*, *slinear*, *quadratic* and *cubic* refer to a [spline](https://en.wikipedia.org/wiki/Spline) interpolation of zeroth, first, second or third order; *previous* and *next* simply return the previous or next value of the point.

# %% [markdown]
# **SPLINE**
#
# piecewise function defined in different intervals, find best polynomial connecting the edges of each interval
#
# idea the derivative of the polynomials must be compatible

# %%
# cubic interpolation
cubic_interp = interp1d(measured_time, measures, kind='cubic')

#kind= choos the degree of the polynomial

# %%
# denser interval to plot the interpolating function
interpolation_time = np.linspace(0, 1, 50)

plt.figure(figsize=(6, 4))
plt.plot(measured_time, measures, 'o', ms=6, label='measures')
#measures should correspond to a sinusoid ] some noise that we defined before


#try with a linear spline interpolation
linear_results = linear_interp(interpolation_time)
plt.plot(interpolation_time, linear_results, label='linear interp')


#try with a cubic interpolation
#more suitable description
cubic_results = cubic_interp(interpolation_time)
plt.plot(interpolation_time, cubic_results, label='cubic interp')
plt.legend()


#NOTE: THESE ARE NOT FITS!!!! JUST INTERPOLATION FUNCTIONS

# %%
# checking the punctual results
x=1/4.
print ("sin(x):",np.sin(2 * np.pi * x), 
       "linear prediction:",linear_interp(x),
       "cubic prediction:", cubic_interp(x))

#estimate the measurement at x=1/4
#with each function, original sine, linear,cubic
# Out:
# sin(x): 1.0 linear prediction: 0.9358646529391801 cubic prediction: 0.9792749511729356

# %% [markdown]
# this kind of interpolation is not used in scientific work.... it's better to do a fit

# %% [markdown]
# # Optimization and fit: `scipy.optimize`
#
# Optimization is the problem of finding a numerical solution to a minimization or equality.
#
# The `scipy.optimize` module provides algorithms for function minimization (scalar or multi-dimensional), curve fitting and root finding.

# %%
from scipy import optimize

# %% [markdown]
# Note **machine learning** very important = equivalent to fitting
#
# in physics you start from a well defined hypothesis
#
# typically you have a well defined model, then run an experiment to check and test model and underlying theory
#
# we typically do experiments knowing what we should expect
#
# in other fields it's not the same, for instance in medicine, try and then collect data with no ideas on the behaviour
#
# in physics we have a strong bias on the distribution describing our data
#
# some parameters of the model must be fixed!
#
#
# datascience and machine learning became important because provide means to get inference from data without having a specific model in mind

# %% [markdown]
# ## Curve Fitting
#
# Fitting is the core business of data analysis or in general data science. If you *know* the underlying model, then the overall problem is simple. If you don't, then it is a very delicate issue.

# %%
from IPython.display import Image
Image("xkcd_curve_fitting.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/ubuntu-16.04/conda/lib/python3.6/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1253         try:
# -> 1254             b64_data = b2a_base64(self.data).decode('ascii')
#    1255         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /opt/ubuntu-16.04/conda/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# /opt/ubuntu-16.04/conda/lib/python3.6/site-packages/IPython/core/display.py in _repr_mimebundle_(self, include, exclude)
#    1242         if self.embed:
#    1243             mimetype = self._mimetype
# -> 1244             data, metadata = self._data_and_metadata(always_both=True)
#    1245             if metadata:
#    1246                 metadata = {mimetype: metadata}
#
# /opt/ubuntu-16.04/conda/lib/python3.6/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1255         except TypeError:
#    1256             raise FileNotFoundError(
# -> 1257                 "No such file or directory: '%s'" % (self.data))
#    1258         md = {}
#    1259         if self.metadata:
#
# FileNotFoundError: No such file or directory: 'xkcd_curve_fitting.png'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/ubuntu-16.04/conda/lib/python3.6/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1253         try:
# -> 1254             b64_data = b2a_base64(self.data).decode('ascii')
#    1255         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /opt/ubuntu-16.04/conda/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /opt/ubuntu-16.04/conda/lib/python3.6/site-packages/IPython/core/display.py in _repr_png_(self)
#    1272     def _repr_png_(self):
#    1273         if self.embed and self.format == self._FMT_PNG:
# -> 1274             return self._data_and_metadata()
#    1275
#    1276     def _repr_jpeg_(self):
#
# /opt/ubuntu-16.04/conda/lib/python3.6/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1255         except TypeError:
#    1256             raise FileNotFoundError(
# -> 1257                 "No such file or directory: '%s'" % (self.data))
#    1258         md = {}
#    1259         if self.metadata:
#
# FileNotFoundError: No such file or directory: 'xkcd_curve_fitting.png'

# %% [markdown]
# Let's take some data, sampled from a sine distribution and affected by random noise

# %%
x_data = np.linspace(-5, 5, num=50)
y_data = 2.9 * np.sin(1.5 * x_data) + np.random.normal(size=50) #just a sinus with random noise

import matplotlib.pyplot as plt
plt.figure(figsize=(6, 4))
plt.scatter(x_data, y_data)

# %% [markdown]
# If we *known* that the data is sampled from a sine function and we just need to find its parameters, in this case amplitude and frequency, we can do that by least squares curve fitting.

# %%
#define our sine function with 2 parameters
#we assume our data are described by a sinus

def f(x, A, nu):
    return A * np.sin(nu * x)

# %%
# fit by means of curve_fit
# p0 are the guessed values for the parameters (amplitude and frequency)

#you'll get both your parameters and your covariance matrix
params, params_covariance = optimize.curve_fit(f, x_data, y_data, p0=[2, 2])

#curve fitting take the fit function, x,y and parameters initial values
#note the proble is always a minimization, you're minimizing a function
#here you minimize the chi^2

#if you provide guess parameters that are too far, the minimization will fail!!


print(params)
print (params_covariance)

# get the full output
#optimize.curve_fit(f, x_data, y_data, p0=[2, 2], full_output=True)
# Out:
# [3.1106 1.5182]
# [[ 0.0408 -0.0005]
#  [-0.0005  0.0005]]

# %% [markdown]
# As every fitting problem, this transaltes into a minimization problem: the function `f(x_data; params)-y_data` is minimized

# %%
plt.scatter(x_data, y_data, label='Data')
plt.plot(x_data, f(x_data, params[0], params[1]),
         label='Fitted function')

plt.legend(loc='best')

# %% [markdown]
# ##  Roots of scalar and functions
#
# Several methods are there for $f(x): {\rm I\!R} \to {\rm I\!R}$, e.g. [Newton-Raphson](https://en.wikipedia.org/wiki/Newton%27s_method) or Brent (a safer version of the secant method, which combines a bracketing strategy with a parabolic approximation)

# %% [markdown]
# finding the roots of a scalar function ( roots= zeros of the function, you can just use secante method, useful when you have an equation)

# %%
def f(x):
    return x**3-3*x+1

x = np.linspace(-3,3,100)
plt.axhline(0)
plt.plot(x, f(x),'r-');

# %%
from scipy.optimize import brentq
brentq(f, -3, 0), brentq(f, 0, 1), brentq(f, 1,3)


#you need to provide an interval where to find your roots
# Out:
# (-1.8794, 0.3473, 1.5321)

# %%
from scipy.optimize import newton
newton(f, -3), newton(f, 0), newton(f, 3)
# Out:
# (-1.8794, 0.3473, 1.5321)

# %% [markdown]
# In case of $f(x): {\rm I\!R}^2 \to {\rm I\!R}$, the `optimize.root` is available, also implementing several methods (MINPACK's hybrd being the default)

# %% [markdown]
# you can do it also for R2-> R functions, but is is rather uncommon.... typically it's a one dimensional

# %%
from scipy.optimize import root, fsolve

def f(x):
    return [x[1] - 3*x[0]*(x[0]+1)*(x[0]-1),
            .25*x[0]**2 + x[1]**2 - 1]

solutions = root(f, (0.5, 0.5))
print (solutions)

print (f(solutions.x))
# Out:
#     fjac: array([[-0.9978,  0.0659],
#        [-0.0659, -0.9978]])
#      fun: array([-1.6360e-12,  1.6187e-12])
#  message: 'The solution converged.'
#     nfev: 21
#      qtf: array([-1.4947e-08,  1.2702e-08])
#        r: array([ 8.2295, -0.8826, -1.7265])
#   status: 1
#  success: True
#        x: array([1.1169, 0.8295])
# [-1.6360246490876307e-12, 1.6187051699034782e-12]

# %% [markdown]
# ## Minimization of a function
#
# The `minimize_scalar` function will find the minimum, and can also be told to search within given bounds. By default, it uses the Brent algorithm.

# %%
def f(x):
    return x**4 + 3*(x-2)**3 - 15*(x)**2 + 1

x = np.linspace(-8, 5, 100)
plt.plot(x, f(x));

# %%
#use minimize scalar for 1D function, use Brent method
optimize.minimize_scalar(f, method='Brent')
# Out:
#      fun: -1.0
#     nfev: 11
#      nit: 7
#  success: True
#        x: 1.0

# %%
optimize.minimize_scalar(f, method='bounded', bounds=[0, 6])
# Out:
#      fun: -0.9999999999996263
#  message: 'Solution found.'
#     nfev: 13
#   status: 0
#  success: True
#        x: 1.0000003530417179

# %% [markdown]
# ### Local and global minima

# %% [markdown]
# you may have a function that hase many minima...difficult to find out global and local ones and classify them...
# standard library may fail also for 1D functions....

# %%
def f(x, offset):
    return -np.sinc(x-offset)

x = np.linspace(-20, 20, 100)
plt.plot(x, f(x, 5));

# %%
# note how additional function arguments are passed in
solution = optimize.minimize_scalar(f, args=(5,))
solution
# Out:
#      fun: -0.049029624014074166
#     nfev: 15
#      nit: 10
#  success: True
#        x: -1.4843871263953001

# %% [markdown]
# Optimization results are packed accordingly to  this [format](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.OptimizeResult.html#scipy.optimize.OptimizeResult)

# %%
plt.plot(x, f(x, 5))
plt.axvline(solution.x,color='b')

# %% [markdown]
# When the function oscillates a lot, often the global minimum is not found. To cope with that, several ranges needs to be explored

# %% [markdown]
# you can divide you domain in several intervals, find the minimum for each one, then find the minimum of all the minima

# %%
lower = np.random.uniform(-20, 20, 100)
upper = lower + 1
solutions = [optimize.minimize_scalar(f, args=(5,), bracket=(l, u)) for (l, u) in zip(lower, upper)]

# %%
idx = np.argmin([solution.fun for solution in solutions])
solution = solutions[idx]

plt.plot(x, f(x, 5))
plt.axvline(solution.x, color='b');

# %% [markdown]
# Alternatively a dedicated method is available

# %%
from scipy.optimize import basinhopping

x0 = 0
solution = basinhopping(f, x0, stepsize=1, minimizer_kwargs={'args': (5,)})
solution
# Out:
#                         fun: -1.0
#  lowest_optimization_result:       fun: -1.0
#  hess_inv: array([[0.304]])
#       jac: array([1.4901e-08])
#   message: 'Optimization terminated successfully.'
#      nfev: 18
#       nit: 5
#      njev: 6
#    status: 0
#   success: True
#         x: array([5.])
#                     message: ['requested number of basinhopping iterations completed successfully']
#       minimization_failures: 0
#                        nfev: 1680
#                         nit: 100
#                        njev: 560
#                           x: array([5.])

# %%
plt.plot(x, f(x, 5))
plt.axvline(solution.x, color='b');

# %% [markdown]
# Minimization of f(x): ${\rm I\!R}^n \to {\rm I\!R}$ is a whole field of study per se. You should have seen it treated in details in other courses.
#
# # Statistics and random numbers: `scipy.stats`
#
# The module scipy.stats contains statistical tools and probabilistic descriptions of random processes. Random number generators for various random process can be found in numpy.random.
#
# Given observations of a random process, their histogram is an estimator of the random process’s PDF (probability density function):

# %% [markdown]
# in scipy there all the pdf that you need, you can actually use these pdf for 2 measurements
#
# 1) to toss data from your chosen pdf, example sample a gamma function to do a montecarlo simulation
#
# 2) datapoints and you have to fit them

# %%
# Sample from a normal distribution using numpy's random number generator
samples = np.random.normal(size=10000)

# Compute a histogram of the sample
bins = np.linspace(-5, 5, 60)

# Compute the PDF on the bin centers from scipy distribution object
from scipy import stats
bin_centers = 0.5*(bins[1:] + bins[:-1])
pdf = stats.norm.pdf(bin_centers)

from matplotlib import pyplot as plt
plt.figure(figsize=(6, 4))
_,_,_ = plt.hist(samples, bins, label="Histogram of samples", density=True)
plt.plot(bin_centers, pdf, label="PDF")
plt.legend()

# %% [markdown]
# If we know that the random process belongs to a given family of random processes, such as normal processes, we can do a maximum-likelihood fit of the observations to estimate the parameters of the underlying distribution. Here we fit a normal process to the observed data:

# %%
mean, std = stats.norm.fit(samples)
print (mean, std)
# Out:
# -0.007563812873795569 0.9903536143879254

# %% [markdown]
# ## Statistical tests
#
# A statistical test is a decision indicator. For instance, if we have two sets of observations, that we assume are generated from Gaussian processes, we can use a [T-test](https://en.wikipedia.org/wiki/Student%27s_t-test) to decide whether the means of two sets of observations are significantly different:

# %% [markdown]
# compare 2 models that fit your data, you want to falsify one of them
#
# if you just do 1 fit, you are not able to tell if your modle is good or not
#
# you cannot tell with just a model if that is a good one or not...
#
# single hypothesis testing is an ill defined test.... you usually want to compare 2 models
#
# you cannot get good conclusions just from chi2 test....

# %%
# Generates 2 sets of observations
samples1 = np.random.normal(0, size=100)
samples2 = np.random.normal(0.1, size=100)

# Compute a histogram of the sample
bins = np.linspace(-4, 4, 30)
histogram1, bins = np.histogram(samples1, bins=bins, density=True)
histogram2, bins = np.histogram(samples2, bins=bins, density=True)

plt.figure(figsize=(6, 4))
plt.hist(samples1, bins=bins, density=True, label="Samples 1")
plt.hist(samples2, bins=bins, density=True, label="Samples 2")
plt.legend(loc='best')

# %%
stats.ttest_ind(samples1, samples2)
# Out:
# Ttest_indResult(statistic=-0.659551976830527, pvalue=0.510307785015798)

# %%
# most of the test statistics are available 
stats.chisquare(samples1,samples2)
# Out:
# Power_divergenceResult(statistic=-172.45157129381016, pvalue=1.0)

# %% [markdown]
# ## Numerical integration: `scipy.integrate`
#
# ### Function integrals
#
# The most generic integration routine is `scipy.integrate.quad()`, which integrate from a to b (possibly infinite interval) using a technique from the Fortran library QUADPACK.
#
#  Let's compute $\int_0^{\pi/2} \sin{\theta}d\theta$:

# %% [markdown]
# there are plenty ways to integrate...
# Montecarlo is useful for high dimensional problems!!

# %%
from scipy.integrate import quad, quadrature
res, err = quad(np.sin, 0, np.pi/2)

# An alternative is the gaussian quadrature
#res, err = quadrature(np.sin, 0, np.pi/2)

print (res, err)
print (np.allclose(res, 1))   # res is the result, is should be close to 1

print (np.allclose(err, 1 - res))  # err is an estimate of the err
# Out:
# 0.9999999999999999 1.1102230246251564e-14
# True
# True

# %% [markdown]
# `scipy.integrate.nquad()` generalize to multiple integration variables

# %% [markdown]
# nquad to go to higher dimension, but you should develop your own code to integrate in multiple dimensions

# %%
from scipy.integrate import nquad
func = lambda x0,x1,x2,x3 : x0**2 + x1*x2 - x3**3 + np.sin(x0) + (
                                1 if (x0-.2*x3-.5-.25*x1>0) else 0)
points = [[lambda x1,x2,x3 : 0.2*x3 + 0.5 + 0.25*x1], [], [], []]
def opts0(*args, **kwargs):
    return {'points':[0.2*args[2] + 0.5 + 0.25*args[0]]} 

result, abserr, out = nquad(func, [[0,1], [-1,1], [.13,.8], [-.15,1]], opts=[opts0,{},{},{}], full_output=True)

print (result, abserr)
print (out)
# Out:
# 1.5267454070738635 2.943736000140233e-14
# {'neval': 388962}

# %% [markdown]
# ### Integrating differential equations
#
# `scipy.integrate` also features routines for integrating Ordinary Differential Equations (ODE). In particular, `scipy.integrate.odeint()` solves ODE of the form:
#
# ```python
# dy/dt = rhs(y1, y2, .., t0,...)
# ```
#
# As an introduction, let us solve the ODE $\frac{dy}{dt} = -2 y$ between $t = 0 \dots 4$, with the initial condition $y(t=0) = 1$. First the function computing the derivative of the position needs to be defined:

# %%
def calc_derivative(ypos, time):
    return -2 * ypos

# %% [markdown]
# Then, to compute y as a function of time:

# %%
from scipy.integrate import odeint
time_vec = np.linspace(0, 4, 40)
y = odeint(calc_derivative, y0=1, t=time_vec)


plt.figure(figsize=(4, 3))
plt.plot(time_vec, y)
plt.xlabel('t: Time')
plt.ylabel('y: Position')
plt.tight_layout()

# %% [markdown]
# Let us integrate a more complex ODE: a damped spring-mass oscillator. The position of a mass attached to a spring obeys the 2nd order ODE $y'' + 2 \varepsilon \omega_0  y' + \omega_0^2 y = 0$ with $\omega_0^2 = k/m$ with $k$ the spring constant, $m$ the mass and $\varepsilon = c/(2 m \omega_0)$ with $c$ the damping coefficient. We set:

# %%
mass = 0.5  # kg
kspring = 4  # N/m
cviscous = 0.4  # N s/m

# and thus
eps = cviscous / (2 * mass * np.sqrt(kspring/mass))
omega = np.sqrt(kspring / mass)

# %% [markdown]
# For `odeint()`, the 2nd order equation needs to be transformed in a system of two first-order equations for the vector $Y = (y, y')$: the function computes the velocity and acceleration:

# %%
def calc_derivative(yvec, time, eps, omega):
    return (yvec[1], -eps * omega * yvec[1] - omega **2 * yvec[0])

# %%
time_vec = np.linspace(0, 10, 100)
yinit = (1, 0)
yarr = odeint(calc_derivative, yinit, time_vec, args=(eps, omega))

# %%
plt.figure(figsize=(4, 3))
plt.plot(time_vec, yarr[:, 0], label='y')
plt.plot(time_vec, yarr[:, 1], label="y'")
plt.legend(loc='best')

# %% [markdown]
# ## Fast Fourier Trasform
#
# The `scipy.fftpack` module computes fast Fourier transforms (FFTs) and offers utilities to handle them. The main functions are:
#
# * `scipy.fftpack.fft()` to compute the FFT
# * `scipy.fftpack.fftfreq()` to generate the sampling frequencies
# * `scipy.fftpack.ifft()` computes the inverse FFT, from frequency space to signal space
#
# Let's generate a noisy signal:

# %%
import numpy as np
from scipy import fftpack
from matplotlib import pyplot as plt

# Seed the random number generator
np.random.seed(1234)

time_step = 0.02
period = 5.

time_vec = np.arange(0, 20, time_step)
sig = (np.sin(2 * np.pi / period * time_vec)
       + 0.5 * np.random.randn(time_vec.size)) #sinus + random noise

plt.figure(figsize=(6, 5))
plt.plot(time_vec, sig, label='Original signal')

# %% [markdown]
# Let's compute and plot the power spectrum
#
# we expect to have 1 frequency with high power, the others are with low power
#
# note: important to check if there other main frequency mattering

# %%
# The FFT of the signal
sig_fft = fftpack.fft(sig)

# And the power (sig_fft is of complex dtype)
power = np.abs(sig_fft)

# The corresponding frequencies
sample_freq = fftpack.fftfreq(sig.size, d=time_step)

# Plot the FFT power
plt.figure(figsize=(6, 5))
plt.plot(sample_freq, power)
plt.xlabel('Frequency [Hz]')
plt.ylabel('plower')


#for some strange reason power spctrum finds out also negative frequency... but negative freq are not physically meaningful
# Find the peak frequency: we can focus on only the positive frequencies
pos_mask = np.where(sample_freq > 0)
freqs = sample_freq[pos_mask]
peak_freq = freqs[power[pos_mask].argmax()]

# Check that it does indeed correspond to the frequency that we generate
# the signal with
print (np.allclose(peak_freq, 1./period))

# An inner plot to show the peak frequency
axes = plt.axes([0.55, 0.3, 0.3, 0.5])
plt.title('Peak frequency')
plt.plot(freqs[:8], power[:8])
plt.setp(axes, yticks=[])

# scipy.signal.find_peaks_cwt can also be used for more advanced
# peak detection
# Out:
# True
# []

# %% [markdown]
# power spectrum= power as function of frequency, we expect a main frequency to be there
#
# you can get the inverse transform after filtering the frequency that you don't care, you can recreate your distribution by doing filtering

# %%
high_freq_fft = sig_fft.copy()
high_freq_fft[np.abs(sample_freq) > peak_freq] = 0
filtered_sig = fftpack.ifft(high_freq_fft)

plt.figure(figsize=(6, 5))
plt.plot(time_vec, sig, label='Original signal')
plt.plot(time_vec, filtered_sig, linewidth=3, label='Filtered signal')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')

plt.legend(loc='best')
# Out:
# /opt/ubuntu-16.04/conda/lib/python3.6/site-packages/numpy/core/numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# summary of lectures
#
# linear algebra and PCA,
#
# basic things that you may want to use in your data analysis
